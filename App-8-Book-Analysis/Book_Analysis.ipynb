# %% [markdown]
# # Load Book

# %%
with open("miracle-in-the-andes.txt", "r", encoding="utf-8") as file:
    book = file.read()

# %%
type(book)
# Out:
# str

# %% [markdown]
# # How many Chapters

# %% [markdown]
# ### with string methods

# %%
book.count("Chapter")
# Out:
# 11

# %% [markdown]
# ## With regrex

# %%
import re

# %%
pattern = re.compile("Chapter [0-9]+")
re.findall(pattern, book)
# Out:
# ['Chapter 1',
#  'Chapter 2',
#  'Chapter 3',
#  'Chapter 4',
#  'Chapter 5',
#  'Chapter 6',
#  'Chapter 7',
#  'Chapter 8',
#  'Chapter 9',
#  'Chapter 10']

# %% [markdown]
# # Which are the sentences in which "Love" word is used"

# %%
pattern = re.compile("[^.]*[^.]*[^a-zA-Z]love[^a-zA-Z][^.]*.")
findings = re.findall(pattern, book)
findings

# %% [markdown]
# # What are the most used words

# %%
pattern = re.compile("[a-zA-Z]+")
findings = re.findall(pattern, book.lower())
findings[:5]
# Out:
# ['chapter', 'before', 'it', 'was', 'friday']

# %%
d = {}
for word in findings:
    if word in d.keys():
        d[word] = d[word] + 1
    else:
        d[word] = 1

# %%
d_list = [(value, key) for (key, value) in d.items()]
sorted(d_list)
